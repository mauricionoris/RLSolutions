# %%
import main as m

# %%
m.config = m.Params(
    total_episodes          =5998,
    learning_rate           =0.1,
    gamma                   =0.8,
    epsilon                 =0.99,
    min_epsilon             =0.05,
    map_size                =5,
    seed                    =42,
    is_slippery             =False,
    n_runs                  =100, 
    action_size             =None,
    state_size              =None,
    proba_frozen            =0.9,
    savefig_folder          ='./fig/',
    env_name                ='CliffWalking-v1',
    render_mode             = {'train': 'rgb_array', 'notebook': 'ansi', 'view': 'human'},
    max_episode_steps_      =50,
    limit_of_stubbornness   =3,
    n_views                 =3,
    act                     = ['down', 'up', 'right', 'left', 'pick', 'drop'],
    starting_state=(3,0)
)

# %%
# %matplotlib inline

mode = 'notebook'
evolution = m.main(mode)
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (South)
#
# step: 13    action: drop     reward: 20 info: [0 1 1 0 1 0] new state: 475

# %%
m.present_charts(evolution, mode)
# Out:
# /mnt/d/uel/25s1/present.py:52: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import gymnasium as gym


gym.__version__
# Out:
# '1.1.1'

# %%
import gymnasium as gym

for env in gym.registry:
    if "CliffWalking" in env:
        print(env)
# Out:
# CliffWalking-v0
# tabular/CliffWalking-v0
