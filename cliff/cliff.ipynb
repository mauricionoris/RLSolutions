# %%
import main as m

# %%
m.config = m.Params(
    total_episodes          =1000,
    learning_rate           =0.1,
    gamma                   =0.8,
    epsilon                 =0.99,
    min_epsilon             =0.05,
    map_size                =5,
    seed                    =42,
    is_slippery             =False,
    n_runs                  =100, 
    action_size             =None,
    state_size              =None,
    proba_frozen            =0.9,
    savefig_folder          ='./fig/',
    env_name                ='CliffWalking-v1',
    render_mode             = {'train': 'rgb_array', 'notebook': 'ansi', 'view': 'human'},
    max_episode_steps_      =100,
    limit_of_stubbornness   =3,
    n_views                 =3,
    act                     = ['down', 'up', 'right', 'left', 'pick', 'drop'],
    starting_state          =(3,0),
    grid                    = m.Grid((4,12),(3,0),(3,11),[(3,1),(3,2),(3,3),(3,4),(3,5),(3,6),(3,7),(3,8),(3,9),(3,10)])
)

# %%
# %matplotlib inline

mode = 'notebook'
evolution, qtable = m.main(mode)
# Out:
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  o
# o  o  o  o  o  o  o  o  o  o  o  x
# o  C  C  C  C  C  C  C  C  C  C  T
#
#
# step: 13    action: right    reward: -1 info: info: info[action_mask] new state: new state: 47

# %%
m.present_charts(evolution, mode,qtable, m.config)
# Out:
# /mnt/d/uel/25s1/RLSolutions/cliff/present.py:67: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
